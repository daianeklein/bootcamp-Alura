# %% [markdown]
# # BOOTCAMP ALURA - ANÁLISE DE DADOS DA SAÚDE

# %% [markdown]
# ## Sobre o projeto

# %% [markdown]
# Data Science Aplicada é um bootcamp promovido pela Alura que consiste em analisar dados da saúde pública brasileira.
# O bootcamp está organizado em módulos com duração de 12 semanas

# %% [markdown]
# ### Organização deste notebook

# %% [markdown]
# Cada módulo é dividido por aulas e cada aula por vídeos e seus respectivos desafios.
#
# Assim, o notebook está organizado por:
# 1. Módulo
# 2. Aulas
# 3. Desafios (Os desafios estarão logo após os métodos ensinados em cada aula, ou seja, será sempre a seção anterior a próxima aula)
#
# ***
#
#
# **MÓDULO 1**
#
# Analisando dados da saúde com Python e Pandas

# %% [markdown]
# ### Datasets Utilizados

# %% [markdown]
# O primeiro dataset é sobre os gastos hospitalares por estado, disponível no DATASUS - Departamento de informática do Sistema Único de Saúde do Brasil
#
# O segundo dataset utilizado para o desafio da aula 03 também foi retirado do DATASUS referente aos dados da Dengue a partir de 2014.

# %% [markdown]
# ## Importação das bibliotecas

# %%
import pandas            as pd
import numpy             as np
import seaborn           as sns

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import warnings
warnings.filterwarnings('ignore')

from io import StringIO

# %% [markdown]
# ## Aula 01 - Aquisição e leitura de dados reais

# %%
# encoding == codificacao
# skiptows == não considera as x primeiras linhas
# skipfooter == não considera as x ultimas linhas
# thousands == Separação do milhar
# decimal == separacao das dezenas

dados = pd.read_csv('A092655189_28_143_208_atendimento.csv',
                   encoding = 'ISO-8859-1', skiprows = 3, skipfooter = 12, sep = ';',
                   thousands = '.',
                   decimal = ',')

# %%
dados
# Out:
#       Unidade da Federação  1992/Mar  1992/Abr  1993/Mai  1993/Dez  1994/Jan  \
# 0              11 Rondônia         -         -         -         -         -
# 1                  12 Acre         -         -         -         -         -
# 2              13 Amazonas         -         -         -         -         -
# 3               14 Roraima         -         -         -         -         -
# 4                  15 Pará         -         -         -         -         -
# 5                 16 Amapá         -         -         -         -         -
# 6             17 Tocantins         -         -         -         -         -
# 7              21 Maranhão         -         -         -         -         -
# 8                 22 Piauí         -         -         -         -         -
# 9                 23 Ceará         -         -         -         -         -
# 10  24 Rio Grande do Norte         -         -         -         -         -
# ...

# %%
dados.tail() # 5 ultimos resultados
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...     2019/Dez     2020/Jan  \
# 22        -        -        -        -  ...  88720873.59  97474362.62
# 23        -        -        -        -  ...  17844511.04  18653296.92
# 24        -        -        -        -  ...  13827706.20  15445693.74
# 25        -        -        -        -  ...  34050298.55  36312121.02
# 26        -        -        -        -  ...  19207148.01  20429067.27
#
#        2020/Fev     2020/Mar     2020/Abr     2020/Mai     2020/Jun  \
# ...

# %%
# informacoes da tabela
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
# Os números são representados em notacão cientifica
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
# configuracao do pandas. Neste caso, estamos alterando o "display" de float para duas casas decimais
pd.options.display.float_format = "{:.2f}".format

# %%
# Visualizando a média após a configuração do display
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
# Media somente da coluna 2008/Ago
dados['2008/Ago'].mean()
# Out:
# 26636409.892222222

# %%
# Primeiro plot
dados.plot(x='Unidade da Federação', y='2008/Ago')

# %%
# plot alterando o tipo de gráfico e o tamanho
dados.plot(x='Unidade da Federação', y='2008/Ago', kind = 'bar', figsize=(8,6))

# %%
ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind = 'bar', figsize=(8,6))

# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

#Titulo do gráfico
plt.title('Valor por unidade da Federação')
# Out:
# Text(0.5, 1.0, 'Valor por unidade da Federação')

# %% [markdown]
# ### Desafio 01: Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.

# %%
ax = dados.sort_values(by='2008/Ago', ascending=False).plot(x='Unidade da Federação', y='2008/Ago', kind = 'bar', figsize=(12,5))

# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

#Titulo do gráfico
plt.title('GASTOS HOSPITALARES PROCESSADOS EM 08/2008 POR UNIDADE DA FEDERAÇÃO',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('Unidade da Federação', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('Gastos Processados', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')

# Remoção das bordas
plt.box(False)


# Removendo a legenda
ax.get_legend().remove()


plt.show()

# %% [markdown]
# ### Desafio 02: Faça a mesma análise realizada em aula, porém para o mês mais recente.

# %% [markdown]
# Não há dados registrados no Acre em 08/2020, portanto, será utilizado o mês julho/2020

# %%
dados[['Unidade da Federação','2020/Ago']]
# Out:
#       Unidade da Federação      2020/Ago
# 0              11 Rondônia    3556381.57
# 1                  12 Acre             -
# 2              13 Amazonas    4726485.73
# 3               14 Roraima    1524478.04
# 4                  15 Pará   11559714.54
# 5                 16 Amapá     834187.31
# 6             17 Tocantins    2453362.74
# 7              21 Maranhão   10916718.78
# 8                 22 Piauí    7926321.69
# 9                 23 Ceará   14559529.59
# 10  24 Rio Grande do Norte    8080160.97
# 11              25 Paraíba    8585226.08
# 12           26 Pernambuco   33544876.14
# 13              27 Alagoas    6487947.82
# 14              28 Sergipe    1742127.72
# 15                29 Bahia   26023558.53
# 16         31 Minas Gerais   57473699.06
# 17       32 Espírito Santo   10824255.26
# 18       33 Rio de Janeiro   36264322.65
# 19            35 São Paulo  140414944.95
# 20               41 Paraná   41542401.16
# 21       42 Santa Catarina   16991236.43
# ...

# %%
dados[['Unidade da Federação','2020/Jul']]
# Out:
#       Unidade da Federação     2020/Jul
# 0              11 Rondônia   7407388.24
# 1                  12 Acre   1163813.08
# 2              13 Amazonas  13358514.02
# 3               14 Roraima   2739498.41
# 4                  15 Pará  27618727.51
# 5                 16 Amapá   2155083.37
# 6             17 Tocantins   4489665.87
# 7              21 Maranhão  24374205.15
# 8                 22 Piauí  18019214.49
# 9                 23 Ceará  30809221.22
# 10  24 Rio Grande do Norte  19593057.45
# 11              25 Paraíba  15491469.06
# 12           26 Pernambuco  62325444.34
# 13              27 Alagoas  13087850.40
# 14              28 Sergipe   3312766.32
# 15                29 Bahia  58898100.40
# 16         31 Minas Gerais 120467187.34
# 17       32 Espírito Santo  27460475.47
# 18       33 Rio de Janeiro  71540227.33
# 19            35 São Paulo 282709570.31
# 20               41 Paraná  80320852.69
# 21       42 Santa Catarina  51764534.76
# ...

# %%
ax = dados.sort_values(by='2008/Ago', ascending=False).plot(x='Unidade da Federação', y='2020/Jul', kind = 'bar', figsize=(12,5))

# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

#Titulo do gráfico
plt.title('GASTOS HOSPITALARES PROCESSADOS EM 07/2020 POR UNIDADE DA FEDERAÇÃO',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('Unidade da Federação', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('Gastos Processados', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')

# Remoção das bordas
plt.box(False)

# Removendo a legenda
ax.get_legend().remove()

plt.show()

# %% [markdown]
# ## Aula 02 - Primeiras Visualizações de Dados

# %%
# Com a funcao mean, o Pandas traz somente os meses que possuem valor (há dados nulos no df)
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
# Uma vez que a funcao mean só irá trazer os meses com valores, serão transformados em indices
# tolist para que os valores sejam transformados em uma lista, caso contrário, os valores ficam imutáveis
colunas_usaveis = dados.mean().index.tolist()

# inserindo a coluna 'Unidade da Federação' na variável colunas_usaveis
colunas_usaveis.insert(0, 'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head(3)
# Out:
#   Unidade da Federação  2007/Ago  2007/Set  2007/Out   2007/Nov   2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03 133645.19  346912.84  711758.31
# 1              12 Acre  10470.07  14001.71  86200.85  301323.68  769612.36
# 2          13 Amazonas  35752.72  45570.64 416012.30 2020381.79 5949408.99
#
#      2008/Jan   2008/Fev   2008/Mar   2008/Abr  ...    2019/Nov    2019/Dez  \
# 0  1829559.71 1940792.63 1955721.68 2143353.81  ...  8948605.66  8660753.05
# 1  1731744.62 1743978.66 2057439.02 2057829.69  ...  3174249.43  2959569.09
# 2 11419210.08 7934652.10 8641517.13 8531576.49  ... 14781332.42 14923380.22
#
#      2020/Jan    2020/Fev    2020/Mar    2020/Abr    2020/Mai    2020/Jun  \
# 0  8326416.32  8413784.42  7174312.31  7423678.64  8581195.13  9193593.76
# 1  3261123.88  2981264.22  2859102.06  2472063.08  2383895.48  2199920.70
# 2 15939561.23 15138110.70 14773739.41 16330913.81 19441150.53 17509334.66
#
#      2020/Jul         Total
# 0  7407388.24  929129659.72
# ...

# %%
# Definindo a coluna 'Unidade da Federação' como índice
usaveis = usaveis.set_index('Unidade da Federação')
usaveis.head(3)
# Out:
#                       2007/Ago  2007/Set  2007/Out   2007/Nov   2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03 133645.19  346912.84  711758.31
# 12 Acre               10470.07  14001.71  86200.85  301323.68  769612.36
# 13 Amazonas           35752.72  45570.64 416012.30 2020381.79 5949408.99
#
#                         2008/Jan   2008/Fev   2008/Mar   2008/Abr   2008/Mai  \
# Unidade da Federação
# 11 Rondônia           1829559.71 1940792.63 1955721.68 2143353.81 2280382.58
# 12 Acre               1731744.62 1743978.66 2057439.02 2057829.69 2226577.93
# 13 Amazonas          11419210.08 7934652.10 8641517.13 8531576.49 9079902.15
#
#                       ...    2019/Nov    2019/Dez    2020/Jan    2020/Fev  \
# Unidade da Federação  ...
# 11 Rondônia           ...  8948605.66  8660753.05  8326416.32  8413784.42
# 12 Acre               ...  3174249.43  2959569.09  3261123.88  2981264.22
# ...

# %%
# Localizando um valor pelo indice
usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
# Transpondo o DataFrame
usaveis.T.head(3)
# Out:
# Unidade da Federação  11 Rondônia  12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37 10470.07     35752.72     4785.91
# 2007/Set                 16397.03 14001.71     45570.64    11858.63
# 2007/Out                133645.19 86200.85    416012.30    43852.67
#
# Unidade da Federação    15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago              181159.29  33672.74       4113.76    385330.18
# 2007/Set              433414.74 104822.98      76633.06   1018352.93
# 2007/Out             1893197.50 118378.28     343702.61   2277717.78
#
# Unidade da Federação   22 Piauí   23 Ceará  ...  32 Espírito Santo  \
# 2007/Ago              220788.25  357904.65  ...           57408.11
# 2007/Set              353468.67  572356.18  ...          284224.80
# 2007/Out             1078182.68 1865065.71  ...         1152115.25
#
# Unidade da Federação  33 Rio de Janeiro  35 São Paulo  41 Paraná  \
# 2007/Ago                      469469.34    1665349.90  554800.22
# ...

# %%
# O grafico abaixo ficou com o eixo Y bastante deslocado, pois na variável 'usaveis' o total está sendo considerado
usaveis.T.plot(figsize=(12,5))

# %%
# Excluindo o 'Total' da variável 'usaveis'
usaveis = usaveis.drop('Total', axis = 1)
usaveis.head(2)
# Out:
#                       2007/Ago  2007/Set  2007/Out  2007/Nov  2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03 133645.19 346912.84 711758.31
# 12 Acre               10470.07  14001.71  86200.85 301323.68 769612.36
#
#                        2008/Jan   2008/Fev   2008/Mar   2008/Abr   2008/Mai  \
# Unidade da Federação
# 11 Rondônia          1829559.71 1940792.63 1955721.68 2143353.81 2280382.58
# 12 Acre              1731744.62 1743978.66 2057439.02 2057829.69 2226577.93
#
#                       ...   2019/Out   2019/Nov   2019/Dez   2020/Jan  \
# Unidade da Federação  ...
# 11 Rondônia           ... 8924348.41 8948605.66 8660753.05 8326416.32
# 12 Acre               ... 3293378.97 3174249.43 2959569.09 3261123.88
#
#                        2020/Fev   2020/Mar   2020/Abr   2020/Mai   2020/Jun  \
# Unidade da Federação
# 11 Rondônia          8413784.42 7174312.31 7423678.64 8581195.13 9193593.76
# ...

# %%
# Plotando novamente o gráfico
usaveis.T.plot(figsize=(12,6))

# %% [markdown]
# ### Desafio 01: Reposicionar a legenda do gráfico em uma posição mais adequada

# %%
# Para configurar o eixo Y, será criada uma variável com o maior valor
maior_valor = usaveis.max(axis=1).max()

# Plotando gráfico
ax = usaveis.T.plot(figsize=(14,6))

# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))


#Titulo do gráfico
plt.title('GASTOS HOSPITALARES ATENDIDOS POR UNIDADE DA FEDERAÇÃO NO PERÍODO DE AGO/07 à JUL/20',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('MM/YY', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('Gastos Atendidos', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(False)

# "Movendo" a legenda
plt.legend(loc=(1.03, -0.1), borderaxespad=0)

# Alterando o eixo Y (comeca do 0, limite será o maior valor do dataset (variavel maior_valor), e 
# o eixo "pula" de 100.000.000 em 100.000.000)
y_ticks = np.arange(0, maior_valor, 100000000)
plt.yticks(y_ticks, color = 'grey', fontsize = 8)

plt.show()

# %% [markdown]
# ### Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência

# %%
#Selecionando 5 estados aleatorios
usaveis_sample = usaveis.sample(5, random_state = 55)

# Para configurar o eixo Y, será criada uma variável com o maior e menor valor
maior_valor2 = usaveis_sample.max(axis=1).max()
menor_valor2 = usaveis_sample.min(axis=1).min()

# Plotando gráfico (funcao sample para plotar 5 estados)
ax = usaveis_sample.T.plot(figsize=(14,6))

# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))


#Titulo do gráfico
plt.title('GASTOS HOSPITALARES ATENDIDOS POR UNIDADE DA FEDERAÇÃO NO PERÍODO DE AGO/07 à JUL/20',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('MM/YY', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('Gastos Atendidos', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(False)

# "Movendo" a legenda
plt.legend(loc=(1.03, -0.1), borderaxespad=0)

# Alterando o eixo Y (comeca do 0, limite será o maior valor do dataset (variavel maior_valor), e 
# o a escala do eixo Y será de 10000000 em 10000000
y_ticks = np.arange(0, maior_valor2, 10000000)
plt.yticks(y_ticks, color = 'grey', fontsize = 8)

plt.show()

# %% [markdown]
# ## Manipulação de Dados

# %%
# Transpondo as colunas da variável 'usaveis'
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
# 5 colunas da variável 'usaveis'
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
# 5 colunas da variavel 'usaveis' pelo indice
usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
# plot dos 5 primeiros estados

usaveis[:5].T.plot(figsize=(10,6))

# %%
# 7 valores aleatórios
usaveis.sample(7)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 28 Sergipe             27453.63   78565.19   122952.94   775705.52
# 53 Distrito Federal   191951.47  769966.25  2165619.56  3813256.48
# 51 Mato Grosso         63562.50  232444.62   927219.59  1740439.60
# 22 Piauí              220788.25  353468.67  1078182.68  2406035.32
# 16 Amapá               33672.74  104822.98   118378.28   226661.18
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1023564534.21 172834914.73 170481849.56
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 28 Sergipe            2765495.63    5439985.99   4636850.76   5017838.07
# 53 Distrito Federal   7121965.42   10561085.46  10215956.80  11627918.26
# ...

# %%
# definindo o seed
np.random.seed(687942)

# mostrando o dataframe
usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 32 Espírito Santo       57408.11  284224.80  1152115.25  2296383.23
# 31 Minas Gerais        971394.37 2861781.50 10018011.35 21730281.63
# 24 Rio Grande do Norte 134605.36  272088.08   684678.30  1695824.89
# 17 Tocantins             4113.76   76633.06   343702.61  1068685.94
# 53 Distrito Federal    191951.47  769966.25  2165619.56  3813256.48
# 50 Mato Grosso do Sul  199556.12  573675.41  1069816.66  1995899.52
# 16 Amapá                33672.74  104822.98   118378.28   226661.18
#
#                           2007/Dez     2008/Jan    2008/Fev    2008/Mar  \
# Unidade da Federação
# 32 Espírito Santo       5724199.54  16212109.41 10032886.43 12262049.08
# 31 Minas Gerais        43429517.54 205912743.65 70301089.50 79119005.51
# 24 Rio Grande do Norte  4730811.68  11763899.23  9110108.87 10126626.54
# 17 Tocantins            3022200.87   5136474.61  5051932.07  5200151.87
# ...

# %%
#Somando cada um dos estados, ou seja, somando as linhas e criando a coluna total
usaveis['Total'] = usaveis.sum(axis=1)
usaveis.head(2)
# Out:
#                       2007/Ago  2007/Set  2007/Out  2007/Nov  2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03 133645.19 346912.84 711758.31
# 12 Acre               10470.07  14001.71  86200.85 301323.68 769612.36
#
#                        2008/Jan   2008/Fev   2008/Mar   2008/Abr   2008/Mai  \
# Unidade da Federação
# 11 Rondônia          1829559.71 1940792.63 1955721.68 2143353.81 2280382.58
# 12 Acre              1731744.62 1743978.66 2057439.02 2057829.69 2226577.93
#
#                       ...   2019/Nov   2019/Dez   2020/Jan   2020/Fev  \
# Unidade da Federação  ...
# 11 Rondônia           ... 8948605.66 8660753.05 8326416.32 8413784.42
# 12 Acre               ... 3174249.43 2959569.09 3261123.88 2981264.22
#
#                        2020/Mar   2020/Abr   2020/Mai   2020/Jun   2020/Jul  \
# Unidade da Federação
# 11 Rondônia          7174312.31 7423678.64 8581195.13 9193593.76 7407388.24
# ...

# %%
# Fazendo a ordenacao por total e excluindo a coluna
ordenado_por_total = usaveis.sort_values(by='Total', ascending=False)
ordenado_por_total = ordenado_por_total.drop('Total', axis = 1)
ordenado_por_total.head(2)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1023564534.21 172834914.73 170481849.56
# 31 Minas Gerais      43429517.54  205912743.65  70301089.50  79119005.51
#
#                          2008/Abr     2008/Mai  ...     2019/Out     2019/Nov  \
# Unidade da Federação                            ...
# 35 São Paulo         170278285.95 172402180.59  ... 303382527.10 282391773.21
# 31 Minas Gerais       79046322.41  79268070.12  ... 166133803.32 152106660.17
#
#                          2019/Dez     2020/Jan     2020/Fev     2020/Mar  \
# Unidade da Federação
# 35 São Paulo         272697695.04 301991167.67 271356784.04 276606288.92
# ...

# %%
# plot do grafico ordenado por total
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
# removendo a coluna com gastos muito elevados
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
# Plot do gráfico
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %% [markdown]
# ### Desafio 01: Escolher uma palete de cores mais adequada do matplotlib.

# %%
# será utilizado a varíavel 'ordenado_por_total'
ax = ordenado_por_total.sample(5, random_state = 35).T.plot(figsize=(13, 5), colormap = 'plasma')


# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
 

#Titulo do gráfico
plt.title('GASTOS HOSPITALARES ATENDIDOS POR UNIDADE DA FEDERAÇÃO NO PERÍODO A PARTIR DE 02/2008',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('MM/YY', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('Gastos Atendidos', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(False)

# "Movendo" a legenda
plt.legend(loc=(1.13, -0.2), borderaxespad=0)

# Configurando o eixo Y
# Obtendo o maior valor
maior_valor = ordenado_por_total.sample(5, random_state = 35).max().max()

y_ticks = np.arange(0, maior_valor, 15000000)
plt.yticks(y_ticks, color = 'grey', fontsize = 8)

plt.show()

# %% [markdown]
# ### Desafio 02: Adicionar uma coluna mostrando a região (Norte, Nodeste, Sul, Suldeste e Centro-Oeste) de cada estado.

# %%
# extraindo a primeira "letra" da string 
#regioes = ordenado_por_total.index.str[0]

# Dicionario com as regiões
rg = {'1':'norte', '2':'nordeste', '3':'sudeste', '4':'sul', '5':'centro-oeste'}

# Funcao map para criar as colunas
# index.str[0] fará um "slice" bucando a primeira letra da coluna 'Unidade da Federacao'
# map irá fazer a busca dos valores
ordenado_por_total['regiao'] = ordenado_por_total.index.str[0].map(rg)

# %%
# Conferindo
ordenado_por_total['regiao'].sample(3)
# Out:
# Unidade da Federação
# 28 Sergipe                   nordeste
# 27 Alagoas                   nordeste
# 50 Mato Grosso do Sul    centro-oeste
# Name: regiao, dtype: object

# %% [markdown]
# ### Desafio 03: Formatar o gráfico de custos por mês dos 5 estados, deixando ele agradável (Bonitão, segundo o Gui)

# %%
# será utilizado a varíavel 'ordenado_por_total'
ax = ordenado_por_total.sample(5, random_state = 35).T[:-1].plot(figsize=(13, 5), colormap = 'plasma')


# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
 

#Titulo do gráfico
plt.title('GASTOS HOSPITALARES ATENDIDOS POR UNIDADE DA FEDERAÇÃO NO PERÍODO A PARTIR DE 02/2008',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('MM/YY', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('Gastos Atendidos', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(False)

# "Movendo" a legenda
plt.legend(loc=(1.13, -0.2), borderaxespad=0)

# Configurando o eixo Y
# Obtendo o maior valor
ordenado_por_total.sample(5, random_state = 35).T[:-1].max().max()

y_ticks = np.arange(0, maior_valor, 15000000)
plt.yticks(y_ticks, color = 'grey', fontsize = 8)

plt.show()

# %% [markdown]
# ### Desafio 04: Adicione o seu estado aos 5 estados plotados anteriormente

# %%
# criando a variável com os estados
plot = ordenado_por_total.sample(5, random_state = 35).T[:-1]

# Criando df "transposto"
ordenado_por_total_T = ordenado_por_total.T[:-1]

# Selecionando o estado de SP
ordenado_por_total_T.loc[:, '35 São Paulo']

# add na variável plot
plot['35 São Paulo'] = ordenado_por_total_T.loc[:, '35 São Paulo']
plot.head(2)
# Out:
# Unidade da Federação 14 Roraima     15 Pará 17 Tocantins 33 Rio de Janeiro  \
# 2008/Fev              771687.83 20126081.01   5051932.07       44122593.19
# 2008/Mar              876091.18 22149375.82   5200151.87       42892665.52
#
# Unidade da Federação 26 Pernambuco 35 São Paulo
# 2008/Fev               26222079.10 172834914.73
# 2008/Mar               30716361.81 170481849.56

# %%
# será utilizado a varíavel 'ordenado_por_total'
ax = plot.plot(figsize=(13, 5), colormap = 'plasma')


# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
 

#Titulo do gráfico
plt.title('GASTOS HOSPITALARES ATENDIDOS POR UNIDADE DA FEDERAÇÃO NO PERÍODO A PARTIR DE 02/2008',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('MM/YY', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('Gastos Atendidos', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(False)

# "Movendo" a legenda
plt.legend(loc=(1.13, -0.2), borderaxespad=0)

# Configurando o eixo Y
# Obtendo o maior valor
maior_valor = plot.max().max()

y_ticks = np.arange(0, maior_valor, 15000000)
plt.yticks(y_ticks, color = 'grey', fontsize = 8)

plt.show()

# %% [markdown]
# ### Desafio 05: Buscar os casos de dengue no Brasil (época de maior número de casos e regiões mais atingidas) e se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de dengue

# %% [markdown]
# O Brasil possui quase que sua totalidade geográfica localizada no hemisfério sul, portanto, para esta análise, vamos considerar as estações do ano baseadas neste hemisfério.
#
#
# Para suportar a análise, utilizaremos a tabela com as datas de inicio e fim de cada estação do ano

# %% [markdown]
# <img aria-describedby="caption-attachment-9529" loading="lazy" class="size-full wp-image-9529" src="https://www.estudokids.com.br/wp-content/uploads/2019/06/hemisferio-terrestre.gif" alt="" width="640" height="382">
# <img src="https://paperx-dex-staging-uploads.s3.sa-east-1.amazonaws.com/images/1588720747098-PJdkb.png" alt="Data das estações">

# %%
df = pd.read_csv('A120000189_28_143_208.csv', encoding = 'ISO-8859-1',
                skiprows = 4, sep =';', skipfooter = 18)

# %%
# Dicionario com as regiões
rg = {'1':'norte', '2':'nordeste', '3':'sudeste', '4':'sul', '5':'centro-oeste'}

# Funcao map para criar as colunas
# index.str[0] fará um "slice" bucando a primeira letra da coluna 'Unidade da Federacao'
# map irá fazer a busca dos valores
df['regiao'] = df['UF de notificação'].str[0].map(rg)

df.sample(3)
# Out:
#     UF de notificação    Jan    Fev    Mar    Abr    Mai    Jun   Jul   Ago  \
# 21  42 Santa Catarina    620   2102   3659   3226   1532    475   158    74
# 18  33 Rio de Janeiro  26419  25844  38683  46639  35542  15783  7958  4868
# 3          14 Roraima    233    153    278    282    329    388   416   474
#
#      Set   Out   Nov    Dez   Total   regiao
# 21    74    96   142    247   12405      sul
# 18  3380  3674  5623  12505  226918  sudeste
# 3    475   460   606    348    4442    norte

# %%
# Criando um dataframe com casos somados por regiao
total_por_regiao = df[:-1].groupby('regiao').sum().T
total_por_regiao = total_por_regiao[:-1]
total_por_regiao
# Out:
# regiao  centro-oeste  nordeste  norte  sudeste    sul
# Jan           100332     71347  23982   249444  14705
# Fev           131850    123447  26122   480522  27924
# Mar           164270    164727  25585   770340  46544
# Abr           152497    178101  20482   871335  50217
# Mai           130928    175173  15460   585112  28432
# Jun            62472    111374   8640   174950   9053
# Jul            24283     76174   6223    52447   2877
# Ago            16183     51312   7442    25780   1602
# Set            14470     36241  12307    20832   1443
# Out            18500     31530  15094    24884   2262
# Nov            28599     43720  17377    38660   5045
# Dez            45367     45926  16451    80057  10152

# %%
# será utilizado a varíavel 'ordenado_por_total'
ax = total_por_regiao.plot(figsize=(13, 5), colormap = 'plasma')

# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
 

#Titulo do gráfico
plt.title('NOTIFICACOES REGISTRADAS SOMADAS DE 2014 à 2019 POR REGIÃO',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('MESES (ANOS ACUMULADOS)', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('NOTIFICACOES REGISTRADAS', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(False)

# "Movendo" a legenda
plt.legend(loc=(1.13, -0.2), borderaxespad=0)

# Configurando o eixo Y
# Obtendo o maior valor
total_max = total_por_regiao.max().max()

y_ticks = np.arange(0, total_max, 40000)
plt.yticks(y_ticks, color = 'grey', fontsize = 8)

plt.show()

# %% [markdown]
# A região sudeste concentra a maior quantidade de pessoas, portanto, **pode** explicar a maior quantidade de casos registrados.
#
# Nota-se que há aumento de notificações dem dezembro, quando inicia o verão, atingindo o pico em abril e então com queda.
#
# Embora abril não seja verão, é provável que as chuvas dos meses anteriores causaram o pico no mes 04.

# %% [markdown]
# ### Desafio 06: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região

# %%
# será utilizado a varíavel 'ordenado_por_total'
ax = ordenado_por_total.groupby('regiao').sum().T[57:-66].plot(figsize=(13, 5), colormap = 'plasma')

# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
 

#Titulo do gráfico
plt.title('GASTOS HOSPITALARES NO PERIODO DE NOV/12 À JAN/15 POR REGIÃO',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('MM/YY', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('GASTOS REGISTRADOS', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(False)

# "Movendo" a legenda
plt.legend(loc=(1.13, -0.2), borderaxespad=0)

# Configurando o eixo Y
# Obtendo o maior valor
maior_valor = ordenado_por_total.groupby('regiao').sum().T[57:-66].max().max()

y_ticks = np.arange(0, maior_valor, 100000000)
plt.yticks(y_ticks, color = 'grey', fontsize = 8)

plt.show()

# %% [markdown]
# Nota-se comportamento semelhante em alguns meses.
#
# Especialmente 02/2013, nas regiões sudeste, nordeste e sul houve aumento nos gastos hospitalares

# %% [markdown]
# ### Desafio 07: Adicionar seu estado escolhido novamente, deixe o gráfico informativo e tire conclusões sobre seus estados comparando com os demais. Tire suas conclusões e compartilhe com a gente.

# %%
# Criando uma variável e resetando index
estados_SP = ordenado_por_total.reset_index()

# boleano - qual é SP e qual não é
eh_sp = estados_SP['Unidade da Federação'] == '35 São Paulo'

# Criando uma coluna nova e inserindo a variavel
estados_SP['eh_sp'] = eh_sp

# conferindo
estados_SP.sample(3)
# Out:
#    Unidade da Federação   2008/Fev    2008/Mar    2008/Abr    2008/Mai  \
# 17             22 Piauí 9711680.20 10428191.09 10227943.00 10562148.66
# 20          13 Amazonas 7934652.10  8641517.13  8531576.49  9079902.15
# 21           28 Sergipe 4636850.76  5017838.07  5265951.03  5367094.94
#
#       2008/Jun    2008/Jul    2008/Ago    2008/Set    2008/Out  ...  \
# 17 10465088.93 10618079.70 10645917.52 11037940.55 11143375.71  ...
# 20  8646295.77  8755806.50  8331763.97  8148089.92  7681661.02  ...
# 21  4981036.36  4928822.87  4543252.50  4525676.82  4566052.38  ...
#
#       2019/Dez    2020/Jan    2020/Fev    2020/Mar    2020/Abr    2020/Mai  \
# 17 16846903.02 17312889.65 16264613.57 15318975.43 11878587.16 14175053.45
# 20 14923380.22 15939561.23 15138110.70 14773739.41 16330913.81 19441150.53
# 21  9230144.57  9605882.99  9160713.54  9193248.73  8395906.57  8450209.57
#
#       2020/Jun    2020/Jul    regiao  eh_sp
# 17 15375523.59 18019214.49  nordeste  False
# ...

# %%
estados_SP[estados_SP['eh_sp'] == False].iloc[:, 0:151].set_index('Unidade da Federação').T.plot()

# %%
# será utilizado a varíavel 'ordenado_por_total'
ax = estados_SP[estados_SP['eh_sp'] == False].iloc[:, 0:151].set_index('Unidade da Federação').T.reset_index().plot.area(figsize=(13, 5), color = 'lightgrey')


# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
 

#Titulo do gráfico
plt.title('GASTOS HOSPITALARES NO PERÍODO DE 02/2008 - 07/2020',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('MESES (ANOS ACUMULADOS)', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('GASTOS', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(False)

# "Movendo" a legenda
plt.legend(loc=(1.13, -0.2), borderaxespad=0)

# Configurando o eixo Y
# Obtendo o maior valor
total_max = estados_SP[estados_SP['eh_sp'] == False].iloc[:, 0:151].set_index('Unidade da Federação').T.max().max()

y_ticks = np.arange(0, total_max, 400000000)
plt.yticks(y_ticks, color = 'grey', fontsize = 8)

plt.show()

# %% [markdown]
# ## Análise de Gráficos e Criação de Hipóteses

# %% [markdown]
# * Desafios feitos nos gráficos anteriores

# %% [markdown]
# # Manipulação e Interpretação de gráfico

# %%
# mes mais recente
mes_mais_recente = ordenado_por_total.columns[-3]
mes_mais_recente
# Out:
# '2020/Jun'

# %%
gastos_dos_mais_recentes = ordenado_por_total[mes_mais_recente]
gastos_dos_mais_recentes
# Out:
# Unidade da Federação
# 35 São Paulo             299060851.62
# 31 Minas Gerais          135977571.87
# 41 Paraná                 92901461.36
# 43 Rio Grande do Sul      89019478.82
# 33 Rio de Janeiro         77604925.21
# 29 Bahia                  65159300.63
# 26 Pernambuco             68145110.59
# 42 Santa Catarina         56503747.99
# 23 Ceará                  42146555.81
# 52 Goiás                  34437633.20
# 15 Pará                   35396030.78
# 21 Maranhão               31128144.66
# 32 Espírito Santo         27450865.16
# 24 Rio Grande do Norte    20219961.81
# 25 Paraíba                19666096.87
# 53 Distrito Federal       23479773.03
# 50 Mato Grosso do Sul     15838659.34
# 22 Piauí                  15375523.59
# 27 Alagoas                14278872.07
# 51 Mato Grosso            14585009.42
# 13 Amazonas               17509334.66
# 28 Sergipe                 6705923.03
# 17 Tocantins               5018138.13
# 11 Rondônia                9193593.76
# ...

# %%
(gastos_dos_mais_recentes / gastos_dos_mais_recentes.loc["33 Rio de Janeiro"]).head(5)
# Out:
# Unidade da Federação
# 35 São Paulo           3.85
# 31 Minas Gerais        1.75
# 41 Paraná              1.20
# 43 Rio Grande do Sul   1.15
# 33 Rio de Janeiro      1.00
# Name: 2020/Jun, dtype: float64

# %%
gastos_dos_mais_recentes.plot(kind = 'bar')

# %% [markdown]
# ### Desafio 01: Buscar na documentação do Matplotlib como colocar um grid nos gráficos e adicionar nos gráficos de barra.

# %%
# será utilizado a varíavel 'ordenado_por_total'
ax = gastos_dos_mais_recentes.plot(kind = 'bar', figsize=(13, 5), colormap = 'plasma')

# Configuracao do eixo Y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

# configurando "grid"
ax.yaxis.grid(color = 'grey', lw = 0.2)

# Colocando "atras" do gráfico
ax.set_axisbelow(True)


#Titulo do gráfico
plt.title('GASTOS HOSPITALARES POR ESTADO',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('UF', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('GASTOS REGISTRADOS', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(True)

maior_valor = gastos_dos_mais_recentes.max()

y_ticks = np.arange(0, maior_valor, 20000000)
plt.yticks(y_ticks, color = 'grey', fontsize = 8)

plt.show()

# %% [markdown]
# # MODULO II

# %%
gastos_proporcionais = gastos_dos_mais_recentes / gastos_dos_mais_recentes.sum()
gastos_proporcionais.plot(kind='bar', figsize=(16,5))

# %%
#lendo arquivo com estimativa da população

ibge_estimativa = pd.read_excel('estimativa_dou_2020.xls')
ibge_estimativa
# Out:
#    ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  \
# 0                      BRASIL E UNIDADES DA FEDERAÇÃO
# 1                                              Brasil
# 2                                        Região Norte
# 3                                            Rondônia
# 4                                                Acre
# 5                                            Amazonas
# 6                                             Roraima
# 7                                                Pará
# 8                                               Amapá
# 9                                           Tocantins
# 10                                    Região Nordeste
# 11                                           Maranhão
# 12                                              Piauí
# 13                                              Ceará
# 14                                Rio Grande do Norte
# ...

# %%
## Tabela com dados do Wikipedia

dados_da_populacao = """Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	46 289 333	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	 Minas Gerais	21 331 292	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 366 189	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 930 634	7,1%	 Chade (14 037 000)
5	 Paraná	11 516 840	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 422 973	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 616 621	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 187 103	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 690 745	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 279 638	3,4%	 Sérvia (7 114 393)
12	 Goiás	7 142 070	3,4%	 Paraguai (7 003 406)
11	 Maranhão	7 127 460	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 228 381	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 064 052	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 039 277	1,9%	 Líbano (4 168 000)
16	 Rio Grande do Norte	3 534 165	1,7%	 Uruguai (3 415 866)
17	 Mato Grosso	3 526 220	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 351 543	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 281 480	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 055 149	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 809 394	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 318 822	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 796 460	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 590 248	0,7%	 Bahrein (1 359 800)
25	 Acre	894 470	0,4%	 Fiji (859 178)
26	 Amapá	861 773	0,4%	 Fiji (859 178)
27	 Roraima	631 181	0,3%	 Luxemburgo (562 958)"""

# %%
dados_da_populacao_io = StringIO(dados_da_populacao)
pd.read_csv(dados_da_populacao_io, sep ='\t')
# Out:
#          Posição    Unidade federativa   População % da pop. total  \
# 0   (habitantes)                   NaN         NaN             NaN
# 1              1             São Paulo  46 289 333           21,9%
# 2              2          Minas Gerais  21 331 292           10,1%
# 3              3        Rio de Janeiro  17 366 189            8,2%
# 4              4           Bahia Bahia  14 930 634            7,1%
# 5              5                Paraná  11 516 840            5,4%
# 6              6     Rio Grande do Sul  11 422 973            5,4%
# 7              7            Pernambuco   9 616 621            4,5%
# 8              8                 Ceará   9 187 103            4,3%
# 9              9             Pará Pará   8 690 745            4,1%
# 10            10        Santa Catarina   7 279 638            3,4%
# 11            12                 Goiás   7 142 070            3,4%
# 12            11              Maranhão   7 127 460            3,4%
# ...

# %%
gastos_dos_mais_recentes.index = gastos_dos_mais_recentes.index.str[3:]
gastos_dos_mais_recentes
# Out:
# Unidade da Federação
# São Paulo             299060851.62
# Minas Gerais          135977571.87
# Paraná                 92901461.36
# Rio Grande do Sul      89019478.82
# Rio de Janeiro         77604925.21
# Bahia                  65159300.63
# Pernambuco             68145110.59
# Santa Catarina         56503747.99
# Ceará                  42146555.81
# Goiás                  34437633.20
# Pará                   35396030.78
# Maranhão               31128144.66
# Espírito Santo         27450865.16
# Rio Grande do Norte    20219961.81
# Paraíba                19666096.87
# Distrito Federal       23479773.03
# Mato Grosso do Sul     15838659.34
# Piauí                  15375523.59
# Alagoas                14278872.07
# Mato Grosso            14585009.42
# Amazonas               17509334.66
# Sergipe                 6705923.03
# Tocantins               5018138.13
# Rondônia                9193593.76
# Acre                    2199920.70
# Roraima                 3216466.51
# ...

# %%
dados_da_populacao_io = StringIO(dados_da_populacao)
populacao = pd.read_csv(dados_da_populacao_io, sep ='\t')
populacao = populacao.dropna()
populacao["populacao"] = populacao["População"].str.replace(" ", "").astype(int)
populacao["uf"] = populacao["Unidade federativa"]
populacao = populacao[["populacao", "uf"]].set_index("uf")
display(populacao.head())
display(populacao.info())
# Out:
#                  populacao
# uf
#  São Paulo        46289333
#  Minas Gerais     21331292
#  Rio de Janeiro   17366189
# Bahia Bahia       14930634
#  Paraná           11516840
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries,  São Paulo to  Roraima
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   populacao  27 non-null     int64
# dtypes: int64(1)
# memory usage: 432.0+ bytes
# None

# %%
populacao.index = populacao.index.str.strip()
populacao.head()
# Out:
#                 populacao
# uf
# São Paulo        46289333
# Minas Gerais     21331292
# Rio de Janeiro   17366189
# Bahia Bahia      14930634
# Paraná           11516840

# %%
for estado in gastos_dos_mais_recentes.index:
  # print(f"{estado} {estado} => {estado}")
  populacao.index = populacao.index.str.replace(f"{estado} {estado}", estado)
populacao.index
# Out:
# Index(['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Bahia', 'Paraná',
#        'Rio Grande do Sul', 'Pernambuco', 'Ceará', 'Pará', 'Santa Catarina',
#        'Goiás', 'Maranhão', 'Amazonas', 'Espírito Santo', 'Paraíba',
#        'Rio Grande do Norte', 'Mato Grosso', 'Alagoas', 'Piauí',
#        'Distrito Federal', 'Mato Grosso do Sul', 'Sergipe', 'Rondônia',
#        'Tocantins', 'Acre', 'Amapá', 'Roraima'],
#       dtype='object', name='uf')

# %%
for estado in populacao.index:
  # print(f"{estado} {estado} => {estado}")
  populacao.index = populacao.index.str.replace(f"{estado} {estado}", estado)
populacao.index
# Out:
# Index(['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Bahia', 'Paraná',
#        'Rio Grande do Sul', 'Pernambuco', 'Ceará', 'Pará', 'Santa Catarina',
#        'Goiás', 'Maranhão', 'Amazonas', 'Espírito Santo', 'Paraíba',
#        'Rio Grande do Norte', 'Mato Grosso', 'Alagoas', 'Piauí',
#        'Distrito Federal', 'Mato Grosso do Sul', 'Sergipe', 'Rondônia',
#        'Tocantins', 'Acre', 'Amapá', 'Roraima'],
#       dtype='object', name='uf')

# %%
gastos_e_populacao_recente = populacao.join(gastos_dos_mais_recentes)
gastos_e_populacao_recente.head()
# Out:
#                 populacao     2020/Jun
# uf
# São Paulo        46289333 299060851.62
# Minas Gerais     21331292 135977571.87
# Rio de Janeiro   17366189  77604925.21
# Bahia            14930634  65159300.63
# Paraná           11516840  92901461.36

# %% [markdown]
# ### Desafio 01 - Entre nos dados do wikipedia e Leia a Base de dados direto do wikipedia.

# %%
wiki = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o')

wiki = wiki[0]

# %%
wiki
# Out:
#     Posição   Unidade federativa   População % da pop. total  \
# 0         1            São Paulo  46 289 333           21,9%
# 1         2         Minas Gerais  21 331 292           10,1%
# 2         3       Rio de Janeiro  17 366 189            8,2%
# 3         4                Bahia  14 930 634            7,1%
# 4         5               Paraná  11 516 840            5,4%
# 5         6    Rio Grande do Sul  11 422 973            5,4%
# 6         7           Pernambuco   9 616 621            4,5%
# 7         8                Ceará   9 187 103            4,3%
# 8         9                 Pará   8 690 745            4,1%
# 9        10       Santa Catarina   7 279 638            3,4%
# 10       12                Goiás   7 142 070            3,4%
# 11       11             Maranhão   7 127 460            3,4%
# 12       13             Amazonas   4 228 381            2,0%
# 13       14       Espírito Santo   4 064 052            1,9%
# ...

# %% [markdown]
# ### Desafio 02 - Neste desafio temos uma série de passos:
#
# Padronizar os nomes das colunas
#
# Transformar os dados nos tipos corretos
#
# Transformar a UF em index

# %%
wiki.columns
# Out:
# Index(['Posição', 'Unidade federativa', 'População', '% da pop. total',
#        'País comparável (habitantes)'],
#       dtype='object')

# %%
# renomeando as colunas
wiki.rename(columns={'Posição' : 'posicao', 
                     'Unidade federativa' : 'uf',
                     'População' : 'populacao', 
                     '% da pop. total':'perc_populacao',
                     'País comparável (habitantes)' : 'pais_comparavel'}, inplace = True)

wiki.drop('posicao', axis = 1, inplace = True)
wiki.set_index('uf', inplace = True)

# %%
# substituindo os espacos em branco da coluna populacao
wiki['populacao'] = wiki['populacao'].str.replace(' ', '')

# Removendo o '%' da coluna perc_populacao
wiki['perc_populacao'] = wiki['perc_populacao'].str.replace('%', '')
wiki
# Out:
#                     populacao perc_populacao  \
# uf
# São Paulo            46289333           21,9
# Minas Gerais         21331292           10,1
# Rio de Janeiro       17366189            8,2
# Bahia                14930634            7,1
# Paraná               11516840            5,4
# Rio Grande do Sul    11422973            5,4
# Pernambuco            9616621            4,5
# Ceará                 9187103            4,3
# Pará                  8690745            4,1
# Santa Catarina        7279638            3,4
# Goiás                 7142070            3,4
# Maranhão              7127460            3,4
# Amazonas              4228381            2,0
# Espírito Santo        4064052            1,9
# Paraíba               4039277            1,9
# Rio Grande do Norte   3534165            1,7
# Mato Grosso           3526220            1,7
# Alagoas               3351543            1,6
# Piauí                 3281480            1,6
# Distrito Federal      3055149            1,4
# ...

# %%
#alterando tipo de dados
wiki['populacao'] = wiki['populacao'].astype('int64')

wiki['perc_populacao'] = wiki['perc_populacao'].str.replace(',', '.')
wiki['perc_populacao'] = wiki['perc_populacao'].astype('float64')

# %%
wiki.dtypes
# Out:
# populacao            int64
# perc_populacao     float64
# pais_comparavel     object
# dtype: object

# %%
wiki
# Out:
#                      populacao  perc_populacao  \
# uf
# São Paulo             46289333           21.90
# Minas Gerais          21331292           10.10
# Rio de Janeiro        17366189            8.20
# Bahia                 14930634            7.10
# Paraná                11516840            5.40
# Rio Grande do Sul     11422973            5.40
# Pernambuco             9616621            4.50
# Ceará                  9187103            4.30
# Pará                   8690745            4.10
# Santa Catarina         7279638            3.40
# Goiás                  7142070            3.40
# Maranhão               7127460            3.40
# Amazonas               4228381            2.00
# Espírito Santo         4064052            1.90
# Paraíba                4039277            1.90
# Rio Grande do Norte    3534165            1.70
# Mato Grosso            3526220            1.70
# Alagoas                3351543            1.60
# Piauí                  3281480            1.60
# ...

# %% [markdown]
# ### Desafio 03 - Buscar na documentação alguns métodos envolvendo strings

# %% [markdown]
# ### Desafio 04 - Desenvolver uma função para a limpeza e tratamento dos dados, retornando duas tabelas "população" e "unida".

# %% [markdown]
# ## AULA 02

# %%
gastos_dos_mais_recentes
# Out:
# Unidade da Federação
# São Paulo             299060851.62
# Minas Gerais          135977571.87
# Paraná                 92901461.36
# Rio Grande do Sul      89019478.82
# Rio de Janeiro         77604925.21
# Bahia                  65159300.63
# Pernambuco             68145110.59
# Santa Catarina         56503747.99
# Ceará                  42146555.81
# Goiás                  34437633.20
# Pará                   35396030.78
# Maranhão               31128144.66
# Espírito Santo         27450865.16
# Rio Grande do Norte    20219961.81
# Paraíba                19666096.87
# Distrito Federal       23479773.03
# Mato Grosso do Sul     15838659.34
# Piauí                  15375523.59
# Alagoas                14278872.07
# Mato Grosso            14585009.42
# Amazonas               17509334.66
# Sergipe                 6705923.03
# Tocantins               5018138.13
# Rondônia                9193593.76
# Acre                    2199920.70
# Roraima                 3216466.51
# ...

# %%
populacao
# Out:
#                      populacao
# uf
# São Paulo             46289333
# Minas Gerais          21331292
# Rio de Janeiro        17366189
# Bahia                 14930634
# Paraná                11516840
# Rio Grande do Sul     11422973
# Pernambuco             9616621
# Ceará                  9187103
# Pará                   8690745
# Santa Catarina         7279638
# Goiás                  7142070
# Maranhão               7127460
# Amazonas               4228381
# Espírito Santo         4064052
# Paraíba                4039277
# Rio Grande do Norte    3534165
# Mato Grosso            3526220
# Alagoas                3351543
# Piauí                  3281480
# Distrito Federal       3055149
# Mato Grosso do Sul     2809394
# Sergipe                2318822
# Rondônia               1796460
# Tocantins              1590248
# Acre                    894470
# Amapá                   861773
# Roraima                 631181

# %%
gastos_e_populacao_recente
# Out:
#                      populacao     2020/Jun
# uf
# São Paulo             46289333 299060851.62
# Minas Gerais          21331292 135977571.87
# Rio de Janeiro        17366189  77604925.21
# Bahia                 14930634  65159300.63
# Paraná                11516840  92901461.36
# Rio Grande do Sul     11422973  89019478.82
# Pernambuco             9616621  68145110.59
# Ceará                  9187103  42146555.81
# Pará                   8690745  35396030.78
# Santa Catarina         7279638  56503747.99
# Goiás                  7142070  34437633.20
# Maranhão               7127460  31128144.66
# Amazonas               4228381  17509334.66
# Espírito Santo         4064052  27450865.16
# Paraíba                4039277  19666096.87
# Rio Grande do Norte    3534165  20219961.81
# Mato Grosso            3526220  14585009.42
# Alagoas                3351543  14278872.07
# Piauí                  3281480  15375523.59
# Distrito Federal       3055149  23479773.03
# ...

# %%
gastos_e_populacao_recente['gastos'] = gastos_e_populacao_recente['2020/Jun'] * 1000000
gastos_e_populacao_recente
# Out:
#                      populacao     2020/Jun             gastos
# uf
# São Paulo             46289333 299060851.62 299060851620000.00
# Minas Gerais          21331292 135977571.87 135977571870000.00
# Rio de Janeiro        17366189  77604925.21  77604925210000.00
# Bahia                 14930634  65159300.63  65159300630000.00
# Paraná                11516840  92901461.36  92901461360000.00
# Rio Grande do Sul     11422973  89019478.82  89019478820000.00
# Pernambuco             9616621  68145110.59  68145110590000.00
# Ceará                  9187103  42146555.81  42146555810000.00
# Pará                   8690745  35396030.78  35396030780000.00
# Santa Catarina         7279638  56503747.99  56503747990000.00
# Goiás                  7142070  34437633.20  34437633200000.00
# Maranhão               7127460  31128144.66  31128144660000.00
# Amazonas               4228381  17509334.66  17509334660000.00
# Espírito Santo         4064052  27450865.16  27450865160000.00
# ...

# %%
gastos_e_populacao_recente['gasto_por_habitante'] = gastos_e_populacao_recente['2020/Jun'] / gastos_e_populacao_recente['populacao']

# %%
gastos_e_populacao_recente.head(3)
# Out:
#                 populacao     2020/Jun             gastos  gasto_por_habitante
# uf
# São Paulo        46289333 299060851.62 299060851620000.00                 6.46
# Minas Gerais     21331292 135977571.87 135977571870000.00                 6.37
# Rio de Janeiro   17366189  77604925.21  77604925210000.00                 4.47

# %%
gastos_e_populacao_recente['gasto_por_habitante'].plot(kind='bar')

# %% [markdown]
# ## Utilizando o Seaborn

# %%
sns.scatterplot(data=gastos_e_populacao_recente, x='populacao', y='gastos')

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=gastos_e_populacao_recente, x='populacao', y='gasto_por_habitante')

# %% [markdown]
# ### Desafio 01: Ordenar o gráfico e criar uma visualização de gastos por habitantes ordenada.

# %%
gastos_e_populacao_recente['gasto_por_habitante'].sort_values(ascending=False).plot(kind='bar', figsize=(15,5))


#Titulo do gráfico
plt.title('GASTOS HOSPITALARES POR HABITANTE',
         pad = 20, fontsize = 14, color = 'dimgrey', fontweight = 'bold')

# Configuracao do eixo X e Y
plt.xlabel('UF', color = 'grey', labelpad = 20, fontsize = 10)
plt.ylabel('GASTOS', color = 'grey', labelpad = 20, fontsize = 10)
plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey')
plt.xticks(rotation=90)

# Remoção das bordas
plt.box(False)

# %% [markdown]
# ## Aula 03 - Ticks, escala e formatação de imagens

# %%
ordenado_por_total.index = ordenado_por_total.index.str[3:]

# %%
sns.scatterplot(x=ordenado_por_total.drop('regiao', axis=1).columns, y=ordenado_por_total.loc['São Paulo'].drop('regiao'))

# %%
mensal = ordenado_por_total.T.drop('regiao')
mensal.head(3)
# Out:
# Unidade da Federação    São Paulo Minas Gerais      Paraná Rio Grande do Sul  \
# 2008/Fev             172834914.73  70301089.50 48855046.46       45897704.82
# 2008/Mar             170481849.56  79119005.51 55611791.07       52928695.92
# 2008/Abr             170278285.95  79046322.41 56115135.82       51972416.77
#
# Unidade da Federação Rio de Janeiro       Bahia  Pernambuco Santa Catarina  \
# 2008/Fev                44122593.19 33410124.06 26222079.10    24409572.92
# 2008/Mar                42892665.52 41301703.40 30716361.81    27483480.50
# 2008/Abr                45295962.86 42826993.62 30589332.79    27806641.44
#
# Unidade da Federação       Ceará       Goiás  ...       Piauí     Alagoas  \
# 2008/Fev             27643304.86 18149374.27  ...  9711680.20  8112220.30
# 2008/Mar             30085370.22 20992213.03  ... 10428191.09  9210505.56
# 2008/Abr             31376221.00 21049477.30  ... 10227943.00 10466691.94
#
# ...

# %%
sns.scatterplot(data = mensal, x = mensal.index, y='São Paulo')

# %%
mensal['São Paulo'] = mensal['São Paulo'].astype('float64')

# AutoLocator
plt.figure(figsize=(16,6))
ax = sns.lineplot(data = mensal, x = mensal.index, y='São Paulo')
plt.xticks(rotation=90)

ax.xaxis.set_major_locator(ticker.AutoLocator())

plt.show()

# %%
# IndexLocator
plt.figure(figsize=(16,6))
ax = sns.lineplot(data = mensal, x = mensal.index, y='São Paulo')
plt.xticks(rotation=90)
plt.ylim(0, 350000000)

ax.xaxis.set_major_locator(ticker.IndexLocator(base=12, offset=0))

plt.show()
