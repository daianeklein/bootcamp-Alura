# %% [markdown]
# # PROJETO MÓDULO II - Data Science Aplicada
#
# ***
#
# ## Visualização de Dados com Seaborn e Matplotlib

# %% [markdown]
#     O projeto do módulo II do Bootcamp Data Science aplicada promovida pela Alura consiste em analisar dados da saúde disponíveis no DATASUS (departamento de informática do Sistema Único de Saúde do Brasil.)
#
#     A análise aborda a evolução de casos de Febre Amarela no país por região e ano, focando na região sudeste, local que registrou mais mais casos do vírus em 2018

# %% [markdown]
# # FEBRE AMARELA

# %% [markdown]
# Febre amarela é uma doença infecciosa. Estudos indicam que o vírus surgiu na África, trazido nos navios que transportavam escravizados para trabalhar nas minas e lavrouras do Brasil.
#
# A febre amarela do tipo silvestre tem o macaco como hospedeiro e transmite a doença através de picadas de mosquitos.
# A forma urbana é transmitida pelo Aedes aegypti, o mesmo mosquito transmissor da dengue, chikungunya e zika.
#
# Vale ressaltar que esta forma surgiu pela última vez em 1942. Após a erradicação, os casos que surgiram foram do tipo silvestre.
#
# **Vacina**
#
# Não existem medicamentos para tratar a doença. Para imunização, existe a vacina de dose única por via subcutânea.
#
# ***
#
# **Cobertura Vacinal**
#
# O dataset leva em consideração os índices de coberturas vacinais. Seguindo o site https://familia.sbim.org.br/, cobertura vacinais se "refere ao percentual da população que está vacinada. Quanto mais pessoas receberem determinada vacina, maior será a cobertura vacinal. A eliminação ou controle de qualquer doença imunoprevenível depende da obtenção desse índice de sucesso."
#
# **Cálculo**
# A fórmula de cálculo da cobertura é o número de doses aplicadas da dose indicada (1ª, 2ª, 3ª dose ou dose única, conforme a vacina) dividida pela população alvo, multiplicado por 100.

# %% [markdown]
# ## Libs Import

# %%
import pandas            as pd
import seaborn           as sns
import numpy             as np

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Dataset import

# %%
df = pd.read_csv('A231837189_28_143_208.csv', sep = ';', encoding = 'latin-1', decimal = ',')
df
# Out:
#                   Região  1994   1995   1996   1997   1998   1999    2000  \
# 0         1 Regiao Norte  6,05  20.81  35.17  50.81  91.68  95.30   95.19
# 1      2 Regiao Nordeste  6,24   5.83   1.58   2.49  10.45  22.86   43.39
# 2        3 RegiaoSudeste     -   0.00   0.02   0.19   6.51  21.01   18.97
# 3           4 Regiao Sul  0,12   0.03   0.01   0.12   0.25   0.18    0.37
# 4  5 Regiao Centro-Oeste   3,5  10.46  19.32  29.55  54.61  65.54  102.35
# 5                  Total  5,27   4.81   5.65   7.84  18.49  29.06   37.14
#
#      2001   2002  ...   2011   2012    2013   2014   2015   2016   2017  \
# 0  105.01  96.32  ...  94.15  94.39   90.83  80.02  75.34  72.56  68.50
# 1   42.13  43.41  ...  43.33  43.24   43.00  38.77  38.90  33.76  33.57
# 2   26.37  22.61  ...  33.48  33.12   33.85  29.76  31.17  29.50  38.95
# 3    1.54   2.57  ...  50.86  56.00   62.15  57.33  58.07  57.28  55.03
# 4   84.38  83.93  ...  82.88  80.85  100.31  99.58  87.17  94.01  80.40
# ...

# %%
df.drop('1994', inplace = True, axis = 1)

# %% [markdown]
# ## Data viz

# %%
df.drop('Total', axis = 1)[:-1]
# Out:
#                   Região   1995   1996   1997   1998   1999    2000    2001  \
# 0         1 Regiao Norte  20.81  35.17  50.81  91.68  95.30   95.19  105.01
# 1      2 Regiao Nordeste   5.83   1.58   2.49  10.45  22.86   43.39   42.13
# 2        3 RegiaoSudeste   0.00   0.02   0.19   6.51  21.01   18.97   26.37
# 3           4 Regiao Sul   0.03   0.01   0.12   0.25   0.18    0.37    1.54
# 4  5 Regiao Centro-Oeste  10.46  19.32  29.55  54.61  65.54  102.35   84.38
#
#     2002   2003  ...   2010   2011   2012    2013   2014   2015   2016   2017  \
# 0  96.32  95.33  ...  95.31  94.15  94.39   90.83  80.02  75.34  72.56  68.50
# 1  43.41  44.20  ...  48.82  43.33  43.24   43.00  38.77  38.90  33.76  33.57
# 2  22.61  10.79  ...  32.07  33.48  33.12   33.85  29.76  31.17  29.50  38.95
# 3   2.57   3.66  ...  45.59  50.86  56.00   62.15  57.33  58.07  57.28  55.03
# 4  83.93  81.99  ...  78.94  82.88  80.85  100.31  99.58  87.17  94.01  80.40
#
#     2018   2019
# 0  68.87  44.04
# ...

# %%
ax = df.drop('Total', axis = 1)[:-1].T[1:].T.sum().plot(figsize=(12,5))

ax = plt.title('COBERTURA VACINAL FEBRE AMARELA NO BRASIL POR ANO',
               pad = 20,
         fontsize = 13, color ='dimgrey', fontweight = 'bold')

sns.despine(bottom = True, left=True)

plt.xlabel('ANOS', color = 'grey', labelpad = 20, fontsize = 8)
plt.ylabel('COBERTURA VACINAL', color = 'grey', labelpad = 20, fontsize = 8)

ax = ax

# %%
ax = df[['Região', 'Total']][1:-1].set_index('Região').plot(kind = 'bar')


ax = plt.title('COBERTURA VACINAL FEBRE AMARELA NO BRASIL POR REGIAO',
               pad = 20,
         fontsize = 13, color ='dimgrey', fontweight = 'bold')

sns.despine(bottom = True, left=True)

plt.xlabel('REGIAO', color = 'grey', labelpad = 20, fontsize = 8)
plt.ylabel('COBERTURA VACINAL', color = 'grey', labelpad = 20, fontsize = 8)

ax = ax

# %% [markdown]
# ### REGIÃO NORDESTE

# %%
ax = df[df['Região'] == '2 Regiao Nordeste'].T[1:-1].plot(figsize=(18,5))

ax = plt.title('COBERTURA VACINAL FEBRE AMARELA NO NORDESTE DO BRASIL',
               pad = 20,
         fontsize = 13, color ='dimgrey', fontweight = 'bold')

sns.despine(bottom = True, left=True)

plt.xlabel('ANOS', color = 'grey', labelpad = 20, fontsize = 8)
plt.ylabel('COBERTURA VACINAL', color = 'grey', labelpad = 20, fontsize = 8)


ax = ax

# %% [markdown]
# ### REGIÃO NORTE

# %%
ax = df[df['Região'] == '1 Regiao Norte'].T[1:-1].plot(figsize=(20,6))

ax = plt.title('COBERTURA VACINAL FEBRE AMARELA NO NORTE DO BRASIL',
               pad = 20,
         fontsize = 13, color ='dimgrey', fontweight = 'bold')

sns.despine(bottom = True, left=True)

plt.xlabel('ANOS', color = 'grey', labelpad = 20, fontsize = 8)
plt.ylabel('COBERTURA VACINAL', color = 'grey', labelpad = 20, fontsize = 8)


ax = ax

# %% [markdown]
# ### Região Sudeste

# %%
ax = df[df['Região'] == '3 RegiaoSudeste'].T[1:-1].plot(figsize=(20,6))

ax = plt.title('COBERTURA VACINAL FEBRE AMARELA NO SUDESTE DO BRASIL',
               pad = 20,
         fontsize = 13, color ='dimgrey', fontweight = 'bold')

sns.despine(bottom = True, left=True)

plt.xlabel('ANOS', color = 'grey', labelpad = 20, fontsize = 8)
plt.ylabel('COBERTURA VACINAL', color = 'grey', labelpad = 20, fontsize = 8)


ax = ax

# %% [markdown]
# ### Região Centro-Oeste

# %%
ax = df[df['Região'] == '5 Regiao Centro-Oeste'].T[1:-1].plot(figsize=(20,6))

ax = plt.title('COBERTURA VACINAL FEBRE AMARELA NO CENTRO-OESTE DO BRASIL',
               pad = 20,
         fontsize = 13, color ='dimgrey', fontweight = 'bold')

sns.despine(bottom = True, left=True)

plt.xlabel('ANOS', color = 'grey', labelpad = 20, fontsize = 8)
plt.ylabel('COBERTURA VACINAL', color = 'grey', labelpad = 20, fontsize = 8)


ax = ax

# %% [markdown]
# ### Região Sul

# %%
ax = df[df['Região'] == '4 Regiao Sul'].T[1:-1].plot(figsize=(20,6))

ax = plt.title('COBERTURA VACINAL FEBRE AMARELA NO SUL DO BRASIL',
               pad = 20,
         fontsize = 13, color ='dimgrey', fontweight = 'bold')

sns.despine(bottom = True, left=True)

plt.xlabel('ANOS', color = 'grey', labelpad = 20, fontsize = 8)
plt.ylabel('COBERTURA VACINAL', color = 'grey', labelpad = 20, fontsize = 8)


ax = ax

# %% [markdown]
# **ALGUMAS CONCLUSÕES**
#
# **1** Nota-se que a região centro oeste é onde se concentram as maiores coberturas vacinais ao longo dos anos
#
# **2** A região sul passou a aumentar a cobertura vacinal somente a partir de 2005
#
# **3** A região nordeste possuem comportamentos bastante semelhante
#
# **4** Houve pico noa região sudeste em 2017/2018 devido ao surto ocorrido principalmente em Minas e São Paulo

# %% [markdown]
# ### Aumento dos índices a partir de 2005

# %%
ax = df.drop('Total', axis = 1)[:-1].T[1:].T.sum().plot(figsize=(12,5))

ax = plt.title('COBERTURA VACINAL FEBRE AMARELA NO BRASIL',
               pad = 20,
         fontsize = 13, color ='dimgrey', fontweight = 'bold')

sns.despine(bottom = True, left=True)

plt.xlabel('ANOS', color = 'grey', labelpad = 20, fontsize = 8)
plt.ylabel('COBERTURA VACINAL', color = 'grey', labelpad = 20, fontsize = 8)

ax = plt.vlines(x=10, linewidth=2, color='#d62728', ymin=0, ymax=400, linestyle='--', 
                label = 'IHC')

ax = ax

# %% [markdown]
# Em todas as regiões do país (especialmente no sul), nota-se aumento dos índices a partir de 2005.
# Conforme pesquisas realizadas, a inclusão do vírus pelo IHC (Internacional Health Care, Cuidado Internacional de Saúde, em tradução livre) como uma ameaça significativa à saúde pública internacional pode ter ocasionado ações em massa para imunização da população.
#
# Com esta inclusão, a necessidade de vacina contra a febre amarela em país alvos também se tornou obrigatória

# %% [markdown]
# ### Surto de febre amarela no Sudeste

# %%
ax = df[df['Região'] == '3 RegiaoSudeste'].T[1:-1].plot(figsize=(10,5), legend=False)

plt.title('COBERTURA VACINAL FEBRE AMARELA NO SUDESTE DO BRASIL',
               pad = 20,
         fontsize = 13, color ='dimgrey', fontweight = 'bold')

sns.despine(bottom = True, left=True)

plt.xlabel('ANOS', color = 'grey', labelpad = 20, fontsize = 8)
plt.ylabel('COBERTURA VACINAL', color = 'grey', labelpad = 20, fontsize = 8)

plt.yticks(fontsize = 10, color = 'dimgrey')
plt.xticks(fontsize = 10, color = 'dimgrey', rotation = 90)

ax = plt.vlines(x=23, linewidth=2, color='#d62728', ymin=0, ymax=75, linestyle='--', 
                label = 'Surto Febre Amarela')


ax = ax

# %% [markdown]
# Nota-se aumento significativo da cobertura da febre amarela em meados de 2018, quando o vírus voltou a registrar aumento.
#
# O número foi ainda maior em São Paulo

# %% [markdown]
# ### Notícias sobre febre amarela no Estado de São Paulo
#
# ***
#
# ***
#
# <img id="fancybox-img" src="https://uploaddeimagens.com.br/images/003/009/300/original/Captura_de_Tela_2020-12-20_a%CC%80s_18.02.42.png?1608498334" alt="">
#
# ***

# %% [markdown]
# <img src = "https://s2.glbimg.com/Mkcb78hGVeOJBg8JxzGu6OutsL8=/0x0:1200x3098/600x0/smart/filters:strip_icc()/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2018/B/h/LifUCdQ1qv4STw6jWtdQ/parques-febre.jpg" width="500" height="600">
